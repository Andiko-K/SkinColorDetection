# %%
import os
import tensorflow as tf

# %%
import numpy as np
from google.colab import files
from tensorflow.keras.utils import load_img, img_to_array

def predict_model(model):

    uploaded = files.upload()

    for fn in uploaded.keys():

      path = '/content/' + fn
      images = tf.io.read_file(path)
      images = tf.image.decode_png (images, channels=3)
      images = tf.image.convert_image_dtype(images, dtype=tf.float32)
      images = tf.image.resize(images, [576,768])
      images = tf.expand_dims(images, axis=0)

      label = ['Tone 1', 'Tone 2', 'Tone 3', 'Tone 4', 'Tone 5', 'Tone 6', 'Tone 7', 'Tone 8', 'Tone 9', 'Tone 10']

      # images = np.vstack([x])
      classes = model.predict(images, batch_size=10)
      prediction = np.argmax(classes[0])
      print(prediction)
      print('result is ' + label[prediction])

      print(classes)

# %% [markdown]
# ### Tone_model
#
# Problem :
# - some missclassfied
# - big model

# %%
# https://github.com/Andiko-K/SkinColorDetection/blob/main/standard-model/tone_model.h5
# !wget wget 'https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model.h5'
# Out:
# --2024-06-06 09:28:31--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2024-06-06 09:28:31--  https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93156384 (89M) [application/octet-stream]
# Saving to: ‘tone_model.h5’
#
# tone_model.h5       100%[===================>]  88.84M  83.8MB/s    in 1.1s
#
# 2024-06-06 09:28:39 (83.8 MB/s) - ‘tone_model.h5’ saved [93156384/93156384]
#
# FINISHED --2024-06-06 09:28:39--
# Total wall clock time: 8.2s
# Downloaded: 1 files, 89M in 1.1s (83.8 MB/s)

# %%
tone_model = tf.keras.models.load_model('tone_model.h5')
predict_model(tone_model)
# Out:
#      <input type="file" id="files-decc988f-3a23-46ba-9720-5a7fb86a6f14" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-decc988f-3a23-46ba-9720-5a7fb86a6f14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Tone_model_mobilenet
#
# Problem : Cropped face = Tone 1

# %%
# !wget wget 'https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet.h5'
# Out:
# --2024-06-06 09:20:42--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2024-06-06 09:20:42--  https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12025176 (11M) [application/octet-stream]
# Saving to: ‘tone_model_mobilenet.h5’
#
# tone_model_mobilene 100%[===================>]  11.47M  34.0MB/s    in 0.3s
#
# 2024-06-06 09:20:43 (34.0 MB/s) - ‘tone_model_mobilenet.h5’ saved [12025176/12025176]
#
# FINISHED --2024-06-06 09:20:43--
# Total wall clock time: 1.4s
# Downloaded: 1 files, 11M in 0.3s (34.0 MB/s)

# %%
tone_model_mobilenet = tf.keras.models.load_model('tone_model_mobilenet.h5')
predict_model(tone_model_mobilenet)
# Out:
#      <input type="file" id="files-d7e22e2f-44c5-4c9f-ab46-52359a9fdb0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7e22e2f-44c5-4c9f-ab46-52359a9fdb0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Tone_model_mobilenet80-512 Unit
#
# Problem : some missclassified Tone 1, 2, 3

# %%
# !wget wget 'https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet80-512unit.h5'
# Out:
# --2024-06-06 09:36:37--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2024-06-06 09:36:37--  https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet80-512unit.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10702888 (10M) [application/octet-stream]
# Saving to: ‘tone_model_mobilenet80-512unit.h5’
#
# tone_model_mobilene 100%[===================>]  10.21M  31.1MB/s    in 0.3s
#
# 2024-06-06 09:36:38 (31.1 MB/s) - ‘tone_model_mobilenet80-512unit.h5’ saved [10702888/10702888]
#
# FINISHED --2024-06-06 09:36:38--
# Total wall clock time: 1.3s
# Downloaded: 1 files, 10M in 0.3s (31.1 MB/s)

# %%
tone_model_mobilenet80_512 = tf.keras.models.load_model('tone_model_mobilenet80-512unit.h5')
predict_model(tone_model_mobilenet80_512)
# Out:
#      <input type="file" id="files-eb726011-d5ad-4a77-ae9c-e1321e8c04c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb726011-d5ad-4a77-ae9c-e1321e8c04c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Tone_model_mobilenet80 128 Unit
#
# Problem : some missclassified Low res Image

# %%
# !wget wget 'https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet80.h5'
# Out:
# --2024-06-06 09:44:34--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2024-06-06 09:44:34--  https://raw.githubusercontent.com/Andiko-K/SkinColorDetection/main/standard-model/tone_model_mobilenet80.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10702960 (10M) [application/octet-stream]
# Saving to: ‘tone_model_mobilenet80.h5’
#
# tone_model_mobilene 100%[===================>]  10.21M  31.1MB/s    in 0.3s
#
# 2024-06-06 09:44:35 (31.1 MB/s) - ‘tone_model_mobilenet80.h5’ saved [10702960/10702960]
#
# FINISHED --2024-06-06 09:44:35--
# Total wall clock time: 1.2s
# Downloaded: 1 files, 10M in 0.3s (31.1 MB/s)

# %%
tone_model_mobilenet80 = tf.keras.models.load_model('tone_model_mobilenet80.h5')
predict_model(tone_model_mobilenet80)
# Out:
#      <input type="file" id="files-218298f3-8ed4-48a3-a921-57b759ee61f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-218298f3-8ed4-48a3-a921-57b759ee61f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
